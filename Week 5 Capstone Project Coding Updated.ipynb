# %% [markdown]
# Source: https://covid19.who.int/table

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'Types of Cases':['Community Transmission', 'Cluster of Cases', 'Sporadic Cases'], 'Number of Countries':[128, 50, 31]})
ax = df.plot.bar(x='Types of Cases', y='Number of Countries' , rot=0)

# %%
Q1 = [5.7, 70.5, 41.2, 132.6, 11, 3.2]
M = [13.1, 223.8, 135.9, 272.2, 42, 9.9]
Q3 = [28.97, 456, 206.8, 519.7, 78.3, 35.6]
index = ['Africa', 'Americas', 'Eastern Mediterranean', 'Europe', 'South-East Asia', 'Western Pacific']
df = pd.DataFrame({'First Quartile': Q1, 'Median': M, 'Third Quartile': Q3}, index=index)
ax = df.plot.bar(stacked=True)
ax.set_ylabel("Deaths per million")
# Out:
# Text(0, 0.5, 'Deaths per million')

# %%
df = pd.DataFrame([[1, 10], [2, 8], [3, 8],[4, 8], [5, 6], [6, 6], [7, 4], [8, 2]], columns=['Category', 'Risk level'])
ax1 = df.plot.scatter(x='Category', y='Risk level', c='DarkBlue')

# %% [markdown]
# X-Axis: Category Labels;
# 1 = Health Workers;
# 2 = 60 Years or Above;
# 3 = Vulnerable;
# 4 = Infants;
# 5 = Essential workers outside health sector;
# 6 = Personnel needed for vaccines, therapeutics, diagnostics production;
# 7 = Government leaders and administrative and technical personnel;
# 8 = Others
